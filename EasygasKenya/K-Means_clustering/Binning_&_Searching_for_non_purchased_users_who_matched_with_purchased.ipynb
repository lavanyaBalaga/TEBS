# %% [markdown]
# # **After Getting the clusters on Non_PURchased and purchased,Here we are passing all the nonpurchased_customers  data rows into purchased_cluster sample, and fetching any user_id of nonpurchased_user matched with the purchased_cluster users**

# %%
df
# Out:
#        customUser:user_Id        date  \
# 0               100117465  11-01-2024
# 1               100117465  28-01-2024
# 2               100122192  02-05-2024
# 3               100122192  03-05-2024
# 4               100376756  01-02-2024
# ...                   ...         ...
# 20462           799986373  15-03-2024
# 20463           799986373  18-02-2024
# 20464           799987903  23-03-2024
# 20465           799987903  25-01-2024
# 20466           799988818  22-12-2023
#
#                                        unifiedScreenName  \
# 0      ['/ProductListing', '/DashboardScreen', '/Prod...
# 1                    ['/DashboardScreen', '/CartScreen']
# 2                                   ['/DashboardScreen']
# 3                   ['/DashboardScreen', '/LoginScreen']
# 4      ['/CartScreen', '/DashboardScreen', '/ProductD...
# ...                                                  ...
# 20462  ['/DashboardScreen', '/ProductDetails', '/Prod...
# ...

# %%
df1=pd.read_csv("/content/non_purchased_users.csv")

# %%
df=df1

# %%
import ast
df['userEngagementDuration'] = df['userEngagementDuration'].apply(ast.literal_eval)
# Function to bin durations
def bin_durations(durations):
    bins = {'A': (0, 30), 'B': (30, 60), 'C': (60, 120), 'D': (120, float('inf'))}
    binned_durations = []

    for duration in durations:
        label = None
        for key, (start, end) in bins.items():
            if start <= duration <= end:
                label = key
                break
        if label is None:
            label = 'D'
        binned_durations.append(label)

    return binned_durations

# Apply binning to Durations column and add a new column to DataFrame
df['BinnedDurations'] = df['userEngagementDuration'].apply(bin_durations)

# Print the updated DataFrame
print(df)
# Out:
#        customUser:user_Id        date  \
# 0               100117465  11-01-2024
# 1               100117465  28-01-2024
# 2               100122192  02-05-2024
# 3               100122192  03-05-2024
# 4               100376756  01-02-2024
# ...                   ...         ...
# 20462           799986373  15-03-2024
# 20463           799986373  18-02-2024
# 20464           799987903  23-03-2024
# 20465           799987903  25-01-2024
# 20466           799988818  22-12-2023
#
#                                        unifiedScreenName  \
# 0      ['/ProductListing', '/DashboardScreen', '/Prod...
# 1                    ['/DashboardScreen', '/CartScreen']
# 2                                   ['/DashboardScreen']
# 3                   ['/DashboardScreen', '/LoginScreen']
# 4      ['/CartScreen', '/DashboardScreen', '/ProductD...
# ...                                                  ...
# 20462  ['/DashboardScreen', '/ProductDetails', '/Prod...
# ...

# %% [markdown]
# # **DAta Binning(Instead of having the individual integers as Engagement durations,considering them as intervals of time)**

# %%
df_non_purchased=pd.read_csv("/content/NON_PURCHASED_USERS.csv")
df_non_purchased
# Out:
#        customUser:user_Id        date  /CartScreen  /DashboardScreen  \
# 0               100117465  2024-01-11            0                27
# 1               100117465  2024-01-28            2                 9
# 2               100122192  2024-05-02            0                15
# 3               100122192  2024-05-03            0                10
# 4               100376756  2024-01-13            7                43
# ...                   ...         ...          ...               ...
# 20462           799986373  2024-03-15            0               103
# 20463           799986373  2024-04-02            0                 0
# 20464           799987903  2024-01-25           54                 0
# 20465           799987903  2024-03-23           63                45
# 20466           799988818  2023-12-22            0                 2
#
#        /LoginScreen  /OffersListPage  /ProductDetails  /ProductListing
# ...

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, random_state=42)
df_non_purchased = df_non_purchased

# Aggregate the data for each user by summing the engagement durations
df_non_purchased_aggregated = df_non_purchased.groupby('customUser:user_Id').sum().reset_index()

# Drop the 'date' column if present, as it's no longer needed
df_non_purchased_aggregated = df_non_purchased_aggregated.drop(columns=['date'])

# %%
df_non_purchased_aggregated
# Out:
#        customUser:user_Id  /CartScreen  /DashboardScreen  /LoginScreen  \
# 0               100117465            2                36             0
# 1               100122192            0                25            11
# 2               100376756          161               785            24
# 3               100448405            4                40            67
# 4               100494415          120               903            64
# ...                   ...          ...               ...           ...
# 10266           799969662          177                 0             0
# 10267           799982209            0                31             0
# 10268           799986373            0               204             6
# 10269           799987903          117                45             0
# 10270           799988818            0                 2             0
#
#        /OffersListPage  /ProductDetails  /ProductListing
# 0                    0               38              154
# ...

# %%
def bin_durations(durations):
    bins = {'zero': 0, 'A': (1, 30), 'B': (30, 60), 'C': (60, 120), 'D': (120, float('inf'))}
    binned_durations = []

    for duration in durations:
        label = None
        for key, value in bins.items():
            if isinstance(value, tuple):
                start, end = value
                if start <= duration <= end:
                    label = key
                    break
            elif duration == value:
                label = key
                break
        if label is None:
            label = 'D'
        binned_durations.append(label)

    return binned_durations
for column in df_non_purchased_aggregated.columns[1:]:
    df_non_purchased_aggregated[column] = bin_durations(df_non_purchased_aggregated[column])

print("Binned Non-Purchased Users Data:")
df_non_purchased_aggregated
# Out:
# Binned Non-Purchased Users Data:
#        customUser:user_Id /CartScreen /DashboardScreen /LoginScreen  \
# 0               100117465           A                B         zero
# 1               100122192        zero                A            A
# 2               100376756           D                D            A
# 3               100448405           A                B            C
# 4               100494415           C                D            C
# ...                   ...         ...              ...          ...
# 10266           799969662           D             zero         zero
# 10267           799982209        zero                B         zero
# 10268           799986373        zero                D            A
# 10269           799987903           C                B         zero
# 10270           799988818        zero                A         zero
#
#       /OffersListPage /ProductDetails /ProductListing
# 0                zero               B               D
# ...

# %%
df1=pd.read_csv("/content/purchased_cluster_0 (1).csv")
df1=df1.drop(['index'],axis=1)
df1
# Out:
#       customUser:user_Id  /CartScreen  /DashboardScreen  /LoginScreen  \
# 0              100148598          4.0              38.0           0.0
# 1              100160846          7.0             217.0          39.0
# 2              100163173          9.0               1.0           8.0
# 3              100176402         20.0              20.0           0.0
# 4              100405046         20.0              38.0          12.0
# ...                  ...          ...               ...           ...
# 8228           799878326          4.0              35.0          23.0
# 8229           799902221         55.0              33.0           0.0
# 8230           799920707         33.0             125.0           0.0
# 8231           799940508          6.0              16.0          18.0
# 8232           799946455         30.0             530.0           0.0
#
#       /OffersListPage  /ProductDetails  /ProductListing
# 0                 0.0              4.0              0.0
# ...

# %%
def bin_durations(durations):
    bins = {'zero': 0, 'A': (1, 30), 'B': (30, 60), 'C': (60, 120), 'D': (120, float('inf'))}
    binned_durations = []

    for duration in durations:
        label = None
        for key, value in bins.items():
            if isinstance(value, tuple):
                start, end = value
                if start <= duration <= end:
                    label = key
                    break
            elif duration == value:
                label = key
                break
        if label is None:
            label = 'D'
        binned_durations.append(label)

    return binned_durations
for column in df1[1:]:
    df1[column] = bin_durations(df1[column])

print("Binned Non-Purchased Users Data:")
df1
#df1=df1.to_csv('df1.csv',index=False)
df1
# Out:
# Binned Non-Purchased Users Data:
#      customUser:user_Id /CartScreen /DashboardScreen /LoginScreen  \
# 0                     D           A                B         zero
# 1                     D           A                D            B
# 2                     D           A                A            A
# 3                     D           A                A         zero
# 4                     D           A                B            A
# ...                 ...         ...              ...          ...
# 8228                  D           A                B            A
# 8229                  D           B                B         zero
# 8230                  D           B                D         zero
# 8231                  D           A                A            A
# 8232                  D           A                D         zero
#
#      /OffersListPage /ProductDetails /ProductListing
# 0               zero               A            zero
# ...

# %%
df_purchased_matches = df1.drop(columns='customUser:user_Id')
df_non_purchased_matches = df_non_purchased_aggregated.drop(columns='customUser:user_Id')

# Convert DataFrames to numpy arrays for comparison
purchased_array = df_purchased_matches.values
non_purchased_array = df_non_purchased_matches.values

# %%
df_purchased_matches.to_csv('df_purchased_matches.csv',index=False)

# %%
matched_indices=[]
for i, non_purchased_row in enumerate(non_purchased_array):
    matched_indices_row = []
    for j, purchased_row in enumerate(purchased_array):
        if np.array_equal(non_purchased_row, purchased_row):
            matched_indices_row.append(j)
    matched_indices.append(matched_indices_row)
matched_users = df_non_purchased_aggregated.copy()
matched_users['matched_purchased_indices'] = matched_indices
matched_users
# Out:
#        customUser:user_Id /CartScreen /DashboardScreen /LoginScreen  \
# 0               100117465           A                B         zero
# 1               100122192        zero                A            A
# 2               100376756           D                D            A
# 3               100448405           A                B            C
# 4               100494415           C                D            C
# ...                   ...         ...              ...          ...
# 10266           799969662           D             zero         zero
# 10267           799982209        zero                B         zero
# 10268           799986373        zero                D            A
# 10269           799987903           C                B         zero
# 10270           799988818        zero                A         zero
#
#       /OffersListPage /ProductDetails /ProductListing  \
# 0                zero               B               D
# ...

# %%
purchased_array.shape
# Out:
# (8233, 6)

# %%
df1.iloc[276:279]
# Out:
#     customUser:user_Id /CartScreen /DashboardScreen /LoginScreen  \
# 276                  D           B                D         zero
# 277                  D           A                D         zero
# 278                  D           C                B         zero
#
#     /OffersListPage /ProductDetails /ProductListing
# 276            zero               A               A
# 277            zero            zero               A
# 278            zero               B               A

# %%
df1.to_csv("df11.csv",index=False)

# %%
df1.shape
# Out:
# (8233, 7)

# %%
matched_users
# Out:
#        customUser:user_Id /CartScreen /DashboardScreen /LoginScreen  \
# 0               100117465           A                B         zero
# 1               100122192        zero                A            A
# 2               100376756           D                D            A
# 3               100448405           A                B            C
# 4               100494415           C                D            C
# ...                   ...         ...              ...          ...
# 10266           799969662           D             zero         zero
# 10267           799982209        zero                B         zero
# 10268           799986373        zero                D            A
# 10269           799987903           C                B         zero
# 10270           799988818        zero                A         zero
#
#       /OffersListPage /ProductDetails /ProductListing  \
# 0                zero               B               D
# ...

# %%
import pandas as pd

import pandas as pd
filtered_users = matched_users[matched_users['matched_purchased_indices'].apply(len) > 0]




filtered_users
# Out:
#        customUser:user_Id /CartScreen /DashboardScreen /LoginScreen  \
# 2               100376756           D                D            A
# 6               101003254           A                A            A
# 7               101021453           A                B            A
# 10              101157311           D                C            B
# 11              101359027           C                C         zero
# ...                   ...         ...              ...          ...
# 10257           799869283           B                C            A
# 10264           799957674           A                A         zero
# 10266           799969662           D             zero         zero
# 10267           799982209        zero                B         zero
# 10269           799987903           C                B         zero
#
#       /OffersListPage /ProductDetails /ProductListing  \
# 2                zero               A               A
# ...

# %%
last_column_df = filtered_users.iloc[:,[0,-1]]
last_column_df
# Out:
#        customUser:user_Id                          matched_purchased_indices
# 2               100376756  [470, 911, 1285, 2280, 2470, 2616, 2751, 2978,...
# 6               101003254  [13, 32, 40, 71, 182, 380, 496, 498, 532, 624,...
# 7               101021453  [5, 10, 19, 334, 336, 761, 909, 1639, 1714, 17...
# 10              101157311                                       [1716, 5042]
# 11              101359027                                       [3585, 5586]
# ...                   ...                                                ...
# 10257           799869283                                        [869, 6966]
# 10264           799957674  [11, 34, 49, 59, 83, 94, 98, 109, 110, 125, 13...
# 10266           799969662                           [5428, 5786, 6374, 7889]
# 10267           799982209                                         [86, 6640]
# 10269           799987903  [278, 1753, 3253, 3268, 3271, 4294, 4363, 7793...
#
# [5034 rows x 2 columns]
