# %% [markdown]
# # Getting the common-sequences from the user behaviour

# %%
import pandas as pd

df = pd.read_csv('original.csv')

df.columns = ['user_id', 'date', 'event_name', 'total_users', 'user_engagement_duration',
              'average_session_duration', 'screen_page_views', 'screen_page_views_per_user', 'event_count']

# Select relevant columns
selected_columns = ['user_id', 'event_name', 'average_session_duration']
user_events = df[selected_columns]

# Group by user_id
grouped = user_events.groupby('user_id')

# Create a dictionary to store the results
user_event_dict = {}

# Iterate through each user and store their events and durations in a list
for user_id, group in grouped:
    events_and_durations = list(zip(group['event_name'], group['average_session_duration']))
    user_event_dict[user_id] = events_and_durations

# Optionally, save the results into a single CSV file for easier analysis
output_df = pd.DataFrame([
    {'user_id': user_id, 'events_and_durations': events}
    for user_id, events in user_event_dict.items()
])
output_df.to_csv('user_events_and_durations.csv', index=False)
output_df
# Out:
#         user_id                               events_and_durations
# 0     100122192  [(home_page, 1e-06), (login, 0.852997), (notif...
# 1     100160846  [(confirm_order_button, 0.001001), (home_page,...
# 2     100376756                                [(app_remove, 0.0)]
# 3     100405016  [(confirm_order_button, 0.002001), (home_deliv...
# 4     100412287  [(confirm_order_button, 0.001001), (home_page,...
# ..          ...                                                ...
# 988   799238995  [(screen_view, 153.7212555), (session_start, 0...
# 989   799440267  [(home_page, 0.0055015), (login, 1.4219895), (...
# 990   799528525  [(login, 1.368989), (screen_view, 691.0530153)...
# 991   799800370  [(login, 1.38399), (notification_receive, 434....
# 992  1122334455  [(page_view, 9.451738), (user_engagement, 1192...
#
# [993 rows x 2 columns]

# %%
successful_users = []
unsuccessful_users = []

for index, row in output_df.iterrows():
    has_confirm_order_button = False
    for event, duration in row['events_and_durations']:
        if event == 'confirm_order_button':
            has_confirm_order_button = True
            break

    if has_confirm_order_button:
        successful_users.append({'user_id': row['user_id'], 'events_and_durations': row['events_and_durations']})
    else:
        unsuccessful_users.append({'user_id': row['user_id'], 'events_and_durations': row['events_and_durations']})

# Create DataFrames for successful and unsuccessful users
df_successful = pd.DataFrame(successful_users)
df_unsuccessful = pd.DataFrame(unsuccessful_users)

df_successful
# Out:
#        user_id                               events_and_durations
# 0    100160846  [(confirm_order_button, 0.001001), (home_page,...
# 1    100405016  [(confirm_order_button, 0.002001), (home_deliv...
# 2    100412287  [(confirm_order_button, 0.001001), (home_page,...
# 3    100428671  [(confirm_order_button, 0.001001), (login, 2.0...
# 4    100448405  [(confirm_order_button, 0.001001), (login, 1.0...
# ..         ...                                                ...
# 238  745064767  [(confirm_order_button, 0.001501), (home_page,...
# 239  746059301  [(confirm_order_button, 0.000501), (login, 2.0...
# 240  772746004  [(confirm_order_button, 0.000501), (home_page,...
# 241  791728308  [(confirm_order_button, 0.002001), (login, 2.0...
# 242  792066937  [(screen_view, 0.799502), (session_start, 0.0)...
#
# [243 rows x 2 columns]

# %%
desired_page_names = [
    "home_page", "login", "order_page", "otp_screen_reached",
    "product_category_clicked", "repeat_order_clicked",
    "reward_page", "session_start", "track_page"
]

# Function to filter pages based on desired_page_names
def filter_pages(events_and_durations):
    return [(event, duration) for event, duration in events_and_durations if event in desired_page_names]

# Filter pages for successful users
df_successful['Filtered Pages'] = df_successful['events_and_durations'].apply(filter_pages)

# Filter pages for unsuccessful users
df_unsuccessful['Filtered Pages'] = df_unsuccessful['events_and_durations'].apply(filter_pages)

# Drop the original 'events_and_durations' column
df_successful.drop(columns=['events_and_durations'], inplace=True)
df_unsuccessful.drop(columns=['events_and_durations'], inplace=True)

# Display the results
print("Successful Users:")
print(df_successful)
print()

print("Unsuccessful Users:")
print(df_unsuccessful)
# Out:
# Successful Users:
#        user_id                                     Filtered Pages
# 0    100160846  [(home_page, 0.001001), (login, 2.006991), (ot...
# 1    100405016  [(login, 0.894998), (session_start, 0.0), (tra...
# 2    100412287  [(home_page, 0.003002), (login, 0.739989), (ot...
# 3    100428671  [(login, 2.009991), (otp_screen_reached, 0.001...
# 4    100448405  [(login, 1.064979), (otp_screen_reached, 0.007...
# ..         ...                                                ...
# 238  745064767  [(home_page, 0.0006676666667), (login, 2.00532...
# 239  746059301  [(login, 2.00348), (session_start, 0.0), (trac...
# 240  772746004  [(home_page, 1.5e-06), (login, 1.2389685), (ot...
# 241  791728308     [(login, 2.0049955), (track_page, 893.447493)]
# 242  792066937  [(session_start, 0.0), (home_page, 0.010501), ...
#
# [243 rows x 2 columns]
#
# Unsuccessful Users:
#         user_id                                     Filtered Pages
# 0     100122192  [(home_page, 1e-06), (login, 0.852997), (track...
# 1     100376756                                                 []
# 2     100494415  [(session_start, 0.0), (otp_screen_reached, 0....
# 3     100898548  [(home_page, 1e-06), (login, 2.003987), (otp_s...
# 4     101003254  [(login, 0.543988), (otp_screen_reached, 1e-06...
# ..          ...                                                ...
# 745   799238995                             [(session_start, 0.0)]
# 746   799440267  [(home_page, 0.0055015), (login, 1.4219895), (...
# 747   799528525      [(login, 1.368989), (track_page, 150.469339)]
# 748   799800370  [(login, 1.38399), (session_start, 0.0), (sess...
# 749  1122334455                                                 []
#
# [750 rows x 2 columns]

# %%
# Define filenames
filename_successful = 'df_successful.csv'
filename_unsuccessful = 'df_unsuccessful.csv'

# Save DataFrames to CSV
df_successful.to_csv(filename_successful, index=False)
df_unsuccessful.to_csv(filename_unsuccessful, index=False)

# %%
df_successful
# Out:
#        user_id                                     Filtered Pages
# 0    100160846  [(home_page, 0.001001), (login, 2.006991), (ot...
# 1    100405016  [(login, 0.894998), (session_start, 0.0), (tra...
# 2    100412287  [(home_page, 0.003002), (login, 0.739989), (ot...
# 3    100428671  [(login, 2.009991), (otp_screen_reached, 0.001...
# 4    100448405  [(login, 1.064979), (otp_screen_reached, 0.007...
# ..         ...                                                ...
# 238  745064767  [(home_page, 0.0006676666667), (login, 2.00532...
# 239  746059301  [(login, 2.00348), (session_start, 0.0), (trac...
# 240  772746004  [(home_page, 1.5e-06), (login, 1.2389685), (ot...
# 241  791728308     [(login, 2.0049955), (track_page, 893.447493)]
# 242  792066937  [(session_start, 0.0), (home_page, 0.010501), ...
#
# [243 rows x 2 columns]

# %%
from collections import Counter
def extract_sequences_with_durations(filtered_pages):
    sequences = []
    current_sequence = []

    for event, duration in filtered_pages:
        if event in desired_page_names:
            current_sequence.append((event, duration))
        else:
            if current_sequence:
                sequences.append(current_sequence)
                current_sequence = []

    if current_sequence:  # Append the last sequence if non-empty
        sequences.append(current_sequence)

    return sequences

# Extract sequences with durations
sequences_successful = []
for filtered_pages in df_successful['Filtered Pages']:
    sequences_successful.extend(extract_sequences_with_durations(filtered_pages))

# Function to find common patterns in sequences
def find_common_patterns(sequences, top_n=20):
    sequence_counter = Counter(tuple(seq) for seq in sequences)
    return sequence_counter.most_common(top_n)

# Find common patterns in successful sequences
common_patterns_successful = find_common_patterns(sequences_successful)

# %%
common_patterns_successful
# Out:
# [((('home_page', 0.001001),
#    ('login', 2.006991),
#    ('otp_screen_reached', 0.001001),
#    ('session_start', 0.0),
#    ('track_page', 82.7355025)),
#   1),
#  ((('login', 0.894998),
#    ('session_start', 0.0),
#    ('track_page', 3.629001),
#    ('otp_screen_reached', 1e-06),
#    ('session_start', 0.0),
#    ('login', 2.008962),
#    ('otp_screen_reached', 1e-06),
#    ('track_page', 3.715004)),
#   1),
#  ((('home_page', 0.003002),
#    ('login', 0.739989),
#    ('otp_screen_reached', 1e-06),
#    ('product_category_clicked', 5.027001),
#    ('track_page', 125.85401)),
#   1),
#  ((('login', 2.009991),
#    ('otp_screen_reached', 0.001001),
#    ('session_start', 0.0),
#    ('track_page', 1.438501)),
#   1),
#  ((('login', 1.064979),
#    ('otp_screen_reached', 0.007004),
#    ('session_start', 0.0)),
#   1),
#  ((('home_page', 0.004001),
#    ('login', 2.007485),
#    ('session_start', 0.0),
#    ('track_page', 39.9232014),
#    ('order_page', 0.003001),
#    ('otp_screen_reached', 0.001001),
#    ('session_start', 0.0)),
#   1),
#  ((('home_page', 0.000501),
#    ('login', 2.003993),
#    ('otp_screen_reached', 0.002002),
#    ('session_start', 0.0),
#    ('track_page', 324.9175025)),
#   1),
#  ((('home_page', 0.001001),
#    ('login', 2.012984),
#    ('otp_screen_reached', 0.001001),
#    ('track_page', 877.154004),
#    ('login', 0.789989),
#    ('otp_screen_reached', 1e-06),
#    ('session_start', 0.0),
#    ('track_page', 3.726002),
#    ('home_page', 0.012001),
#    ('login', 2.010989),
#    ('otp_screen_reached', 0.002001),
#    ('reward_page', 1e-06),
#    ('track_page', 234.168005),
#    ('login', 0.644988),
#    ('otp_screen_reached', 1e-06),
#    ('track_page', 1e-06),
#    ('home_page', 0.006002),
#    ('login', 0.879988),
#    ('otp_screen_reached', 0.002001),
#    ('track_page', 352.852006)),
#   1),
#  ((('login', 0.929989),
#    ('otp_screen_reached', 1e-06),
#    ('session_start', 0.0),
#    ('track_page', 1e-06),
#    ('home_page', 0.001001),
#    ('login', 0.873989),
#    ('otp_screen_reached', 1e-06),
#    ('session_start', 0.0),
#    ('track_page', 5.163502)),
#   1),
#  ((('login', 0.896998),
#    ('otp_screen_reached', 0.001001),
#    ('session_start', 0.0),
#    ('track_page', 0.723001)),
#   1),
#  ((('home_page', 0.00601),
#    ('login', 2.006982),
#    ('track_page', 879.628994),
#    ('otp_screen_reached', 1e-06),
#    ('session_start', 0.0)),
#   1),
#  ((('home_page', 0.001002),
#    ('login', 0.088998),
#    ('otp_screen_reached', 1e-06),
#    ('track_page', 990.773004)),
#   1),
#  ((('login', 2.008999),
#    ('otp_screen_reached', 0.003001),
#    ('track_page', 21.527001)),
#   1),
#  ((('login', 0.413984),
#    ('otp_screen_reached', 0.001001),
#    ('track_page', 2.779002)),
#   1),
#  ((('home_page', 0.001001),
#    ('login', 2.00499),
#    ('otp_screen_reached', 0.001001),
#    ('session_start', 0.0),
#    ('track_page', 2.842001),
#    ('login', 2.005991),
#    ('otp_screen_reached', 0.001001),
#    ('track_page', 32.985003)),
#   1),
#  ((('home_page', 0.001001),
#    ('login', 2.004985),
#    ('track_page', 71.614003),
#    ('session_start', 0.0),
#    ('home_page', 1e-06),
#    ('login', 2.004999),
#    ('otp_screen_reached', 0.001001),
#    ('session_start', 0.0),
#    ('track_page', 1073.508995)),
#   1),
#  ((('home_page', 0.006002),
#    ('login', 0.333989),
#    ('otp_screen_reached', 0.001001),
#    ('track_page', 268.269092)),
#   1),
#  ((('home_page', 1e-06),
#    ('login', 0.40395),
#    ('otp_screen_reached', 0.001001),
#    ('session_start', 0.0),
#    ('track_page', 32.4725015)),
#   1),
#  ((('home_page', 0.001002),
#    ('login', 2.003986),
#    ('otp_screen_reached', 0.002002),
#    ('track_page', 10.295004)),
#   1),
#  ((('home_page', 0.004001),
#    ('login', 0.692984),
#    ('otp_screen_reached', 1e-06),
#    ('session_start', 0.0),
#    ('track_page', 1.865001)),
#   1)]

# %%
def extract_sequences_with_durations(filtered_pages):
    sequences = []
    current_sequence = []

    for event, duration in filtered_pages:
        if event in desired_page_names:
            current_sequence.append((event, duration))
        else:
            if current_sequence:
                sequences.append(current_sequence)
                current_sequence = []

    if current_sequence:  # Append the last sequence if non-empty
        sequences.append(current_sequence)

    return sequences

# Extract sequences with durations
sequences_successful = []
for filtered_pages in df_successful['Filtered Pages']:
    sequences_successful.extend(extract_sequences_with_durations(filtered_pages))

# Function to find common patterns in sequences
def find_common_patterns(sequences, top_n=20):
    sequence_counter = Counter(tuple(seq) for seq in sequences)
    common_patterns = sequence_counter.most_common(top_n)
    return [(pattern, count) for pattern, count in common_patterns]

# Find common patterns in successful sequences
common_patterns_successful = find_common_patterns(sequences_successful)

# Print common patterns
print("Most common sequences in successful users:")
for sequence, count in common_patterns_successful:
    print(f"{sequence}: {count} occurrences")
# Out:
# Most common sequences in successful users:
# (('home_page', 0.001001), ('login', 2.006991), ('otp_screen_reached', 0.001001), ('session_start', 0.0), ('track_page', 82.7355025)): 1 occurrences
# (('login', 0.894998), ('session_start', 0.0), ('track_page', 3.629001), ('otp_screen_reached', 1e-06), ('session_start', 0.0), ('login', 2.008962), ('otp_screen_reached', 1e-06), ('track_page', 3.715004)): 1 occurrences
# (('home_page', 0.003002), ('login', 0.739989), ('otp_screen_reached', 1e-06), ('product_category_clicked', 5.027001), ('track_page', 125.85401)): 1 occurrences
# (('login', 2.009991), ('otp_screen_reached', 0.001001), ('session_start', 0.0), ('track_page', 1.438501)): 1 occurrences
# (('login', 1.064979), ('otp_screen_reached', 0.007004), ('session_start', 0.0)): 1 occurrences
# (('home_page', 0.004001), ('login', 2.007485), ('session_start', 0.0), ('track_page', 39.9232014), ('order_page', 0.003001), ('otp_screen_reached', 0.001001), ('session_start', 0.0)): 1 occurrences
# (('home_page', 0.000501), ('login', 2.003993), ('otp_screen_reached', 0.002002), ('session_start', 0.0), ('track_page', 324.9175025)): 1 occurrences
# (('home_page', 0.001001), ('login', 2.012984), ('otp_screen_reached', 0.001001), ('track_page', 877.154004), ('login', 0.789989), ('otp_screen_reached', 1e-06), ('session_start', 0.0), ('track_page', 3.726002), ('home_page', 0.012001), ('login', 2.010989), ('otp_screen_reached', 0.002001), ('reward_page', 1e-06), ('track_page', 234.168005), ('login', 0.644988), ('otp_screen_reached', 1e-06), ('track_page', 1e-06), ('home_page', 0.006002), ('login', 0.879988), ('otp_screen_reached', 0.002001), ('track_page', 352.852006)): 1 occurrences
# (('login', 0.929989), ('otp_screen_reached', 1e-06), ('session_start', 0.0), ('track_page', 1e-06), ('home_page', 0.001001), ('login', 0.873989), ('otp_screen_reached', 1e-06), ('session_start', 0.0), ('track_page', 5.163502)): 1 occurrences
# (('login', 0.896998), ('otp_screen_reached', 0.001001), ('session_start', 0.0), ('track_page', 0.723001)): 1 occurrences
# (('home_page', 0.00601), ('login', 2.006982), ('track_page', 879.628994), ('otp_screen_reached', 1e-06), ('session_start', 0.0)): 1 occurrences
# (('home_page', 0.001002), ('login', 0.088998), ('otp_screen_reached', 1e-06), ('track_page', 990.773004)): 1 occurrences
# (('login', 2.008999), ('otp_screen_reached', 0.003001), ('track_page', 21.527001)): 1 occurrences
# (('login', 0.413984), ('otp_screen_reached', 0.001001), ('track_page', 2.779002)): 1 occurrences
# (('home_page', 0.001001), ('login', 2.00499), ('otp_screen_reached', 0.001001), ('session_start', 0.0), ('track_page', 2.842001), ('login', 2.005991), ('otp_screen_reached', 0.001001), ('track_page', 32.985003)): 1 occurrences
# (('home_page', 0.001001), ('login', 2.004985), ('track_page', 71.614003), ('session_start', 0.0), ('home_page', 1e-06), ('login', 2.004999), ('otp_screen_reached', 0.001001), ('session_start', 0.0), ('track_page', 1073.508995)): 1 occurrences
# (('home_page', 0.006002), ('login', 0.333989), ('otp_screen_reached', 0.001001), ('track_page', 268.269092)): 1 occurrences
# (('home_page', 1e-06), ('login', 0.40395), ('otp_screen_reached', 0.001001), ('session_start', 0.0), ('track_page', 32.4725015)): 1 occurrences
# (('home_page', 0.001002), ('login', 2.003986), ('otp_screen_reached', 0.002002), ('track_page', 10.295004)): 1 occurrences
# (('home_page', 0.004001), ('login', 0.692984), ('otp_screen_reached', 1e-06), ('session_start', 0.0), ('track_page', 1.865001)): 1 occurrences

# %%
from collections import Counter

# Define the filtered pages (events)
filtered_pages = df_successful['Filtered Pages']

# Extract the pages from the data
pages = [page for user in filtered_pages for page in user]

# Count occurrences of each page
page_counts = Counter(pages)

# Sort the pages by occurrence count
sorted_pages = sorted(page_counts.items(), key=lambda x: x[1], reverse=True)

# Display the sorted pages
print("Most occurred filtered pages:")
for page, count in sorted_pages:
    print(f"{page}: {count} occurrences")
# Out:
# Most occurred filtered pages:
# ('session_start', 0.0): 437 occurrences
# ('otp_screen_reached', 0.001001): 117 occurrences
# ('otp_screen_reached', 1e-06): 81 occurrences
# ('home_page', 1e-06): 55 occurrences
# ('otp_screen_reached', 0.002001): 45 occurrences
# ('home_page', 0.001001): 39 occurrences
# ('order_page', 1e-06): 30 occurrences
# ('order_page', 0.001001): 28 occurrences
# ('otp_screen_reached', 0.003001): 23 occurrences
# ('reward_page', 0.001001): 18 occurrences
# ('track_page', 1e-06): 16 occurrences
# ('home_page', 0.001002): 16 occurrences
# ('home_page', 0.002001): 15 occurrences
# ('reward_page', 1e-06): 14 occurrences
# ('home_page', 2e-06): 11 occurrences
# ('login', 2.004992): 11 occurrences
# ('home_page', 0.002002): 10 occurrences
# ('track_page', 0.001001): 9 occurrences
# ('login', 2.000996): 8 occurrences
# ('order_page', 0.001002): 7 occurrences
# ('login', 2.002992): 7 occurrences
# ('login', 2.003992): 7 occurrences
# ('login', 2.001996): 7 occurrences
# ('order_page', 0.003001): 6 occurrences
# ('otp_screen_reached', 0.004001): 6 occurrences
# ('login', 2.006991): 5 occurrences
# ('login', 2.004991): 5 occurrences
# ('order_page', 2e-06): 5 occurrences
# ('login', 2.005992): 5 occurrences
# ('home_page', 0.004001): 4 occurrences
# ('otp_screen_reached', 0.002002): 4 occurrences
# ('home_page', 0.006002): 4 occurrences
# ('login', 2.00499): 4 occurrences
# ('home_page', 0.0015025): 4 occurrences
# ('login', 2.006992): 4 occurrences
# ('reward_page', 0.002001): 4 occurrences
# ('home_page', 0.001003): 4 occurrences
# ('login', 2.005986): 4 occurrences
# ('login', 2.007992): 4 occurrences
# ('otp_screen_reached', 0.000501): 4 occurrences
# ('login', 2.009991): 3 occurrences
# ('home_page', 0.000501): 3 occurrences
# ('login', 2.005991): 3 occurrences
# ('otp_screen_reached', 2e-06): 3 occurrences
# ('home_page', 0.003001): 3 occurrences
# ('home_page', 0.002003): 3 occurrences
# ('home_page', 0.003004): 3 occurrences
# ('home_page', 0.004002): 3 occurrences
# ('otp_screen_reached', 0.001002): 3 occurrences
# ('login', 2.000999): 3 occurrences
# ('login', 2.001999): 3 occurrences
# ('login', 2.005988): 3 occurrences
# ('order_page', 0.003002): 3 occurrences
# ('home_page', 0.003003): 3 occurrences
# ('home_page', 0.007001): 3 occurrences
# ('order_page', 0.002001): 3 occurrences
# ('login', 2.00799): 3 occurrences
# ('login', 2.003): 3 occurrences
# ('reward_page', 0.002002): 3 occurrences
# ('otp_screen_reached', 0.001501): 3 occurrences
# ('login', 2.003993): 2 occurrences
# ('login', 2.003986): 2 occurrences
# ('login', 2.003985): 2 occurrences
# ('home_page', 0.004003): 2 occurrences
# ('login', 2.00599): 2 occurrences
# ('order_page', 0.016001): 2 occurrences
# ('login', 2.012991): 2 occurrences
# ('login', 2.00999): 2 occurrences
# ('login', 2.007988): 2 occurrences
# ('login', 2.01099): 2 occurrences
# ('login', 2.009983): 2 occurrences
# ('login', 2.008991): 2 occurrences
# ('otp_screen_reached', 0.005002): 2 occurrences
# ('login', 2.012985): 2 occurrences
# ('reward_page', 0.005001): 2 occurrences
# ('login', 2.007991): 2 occurrences
# ('login', 2.002998): 2 occurrences
# ('login', 2.002991): 2 occurrences
# ('login', 2.000986): 2 occurrences
# ('home_page', 0.008001): 2 occurrences
# ('login', 2.004982): 2 occurrences
# ('login', 2.001997): 2 occurrences
# ('reward_page', 0.003001): 2 occurrences
# ('login', 2.004989): 2 occurrences
# ('home_page', 0.0003343333333): 2 occurrences
# ('order_page', 0.014001): 2 occurrences
# ('home_page', 0.006003): 2 occurrences
# ('track_page', 0.002001): 2 occurrences
# ('login', 2.006993): 2 occurrences
# ('login', 2.004996): 2 occurrences
# ('home_page', 0.001001333333): 2 occurrences
# ('login', 2.034991): 2 occurrences
# ('home_page', 0.005002): 2 occurrences
# ('login', 1.998996): 2 occurrences
# ('login', 2.005987): 2 occurrences
# ('home_page', 0.004005): 2 occurrences
# ('reward_page', 0.003002): 2 occurrences
# ('login', 2.007989): 2 occurrences
# ('login', 2.00399): 2 occurrences
# ('login', 2.021992): 2 occurrences
# ('login', 2.00699): 2 occurrences
# ('login', 2.004994): 2 occurrences
# ('login', 2.002983): 2 occurrences
# ('order_page', 0.004001): 2 occurrences
# ('login', 2.008986): 2 occurrences
# ('login', 2.001991): 2 occurrences
# ('home_page', 0.002004): 2 occurrences
# ('login', 2.001993): 2 occurrences
# ('login', 2.0049895): 2 occurrences
# ('track_page', 82.7355025): 1 occurrences
# ('login', 0.894998): 1 occurrences
# ('track_page', 3.629001): 1 occurrences
# ('login', 2.008962): 1 occurrences
# ('track_page', 3.715004): 1 occurrences
# ('home_page', 0.003002): 1 occurrences
# ('login', 0.739989): 1 occurrences
# ('product_category_clicked', 5.027001): 1 occurrences
# ('track_page', 125.85401): 1 occurrences
# ('track_page', 1.438501): 1 occurrences
# ('login', 1.064979): 1 occurrences
# ('otp_screen_reached', 0.007004): 1 occurrences
# ('login', 2.007485): 1 occurrences
# ('track_page', 39.9232014): 1 occurrences
# ('track_page', 324.9175025): 1 occurrences
# ('login', 2.012984): 1 occurrences
# ('track_page', 877.154004): 1 occurrences
# ('login', 0.789989): 1 occurrences
# ('track_page', 3.726002): 1 occurrences
# ('home_page', 0.012001): 1 occurrences
# ('login', 2.010989): 1 occurrences
# ('track_page', 234.168005): 1 occurrences
# ('login', 0.644988): 1 occurrences
# ('login', 0.879988): 1 occurrences
# ('track_page', 352.852006): 1 occurrences
# ('login', 0.929989): 1 occurrences
# ('login', 0.873989): 1 occurrences
# ('track_page', 5.163502): 1 occurrences
# ('login', 0.896998): 1 occurrences
# ('track_page', 0.723001): 1 occurrences
# ('home_page', 0.00601): 1 occurrences
# ('login', 2.006982): 1 occurrences
# ('track_page', 879.628994): 1 occurrences
# ('login', 0.088998): 1 occurrences
# ('track_page', 990.773004): 1 occurrences
# ('login', 2.008999): 1 occurrences
# ('track_page', 21.527001): 1 occurrences
# ('login', 0.413984): 1 occurrences
# ('track_page', 2.779002): 1 occurrences
# ('track_page', 2.842001): 1 occurrences
# ('track_page', 32.985003): 1 occurrences
# ('login', 2.004985): 1 occurrences
# ('track_page', 71.614003): 1 occurrences
# ('login', 2.004999): 1 occurrences
# ('track_page', 1073.508995): 1 occurrences
# ('login', 0.333989): 1 occurrences
# ('track_page', 268.269092): 1 occurrences
# ('login', 0.40395): 1 occurrences
# ('track_page', 32.4725015): 1 occurrences
# ('track_page', 10.295004): 1 occurrences
# ('login', 0.692984): 1 occurrences
# ('track_page', 1.865001): 1 occurrences
# ('track_page', 151.858005): 1 occurrences
# ('login', 0.614988): 1 occurrences
# ('track_page', 9.702001667): 1 occurrences
# ('login', 2.030989): 1 occurrences
# ('login', 0.515986): 1 occurrences
# ('track_page', 1.371002): 1 occurrences
# ('login', 0.702985): 1 occurrences
# ('track_page', 17.673003): 1 occurrences
# ('login', 2.025987): 1 occurrences
# ('track_page', 1002.541008): 1 occurrences
# ('track_page', 73.825019): 1 occurrences
# ('login', 0.919989): 1 occurrences
# ('track_page', 60.3729935): 1 occurrences
# ('login', 2.033991): 1 occurrences
# ('track_page', 100.8875035): 1 occurrences
# ('login', 2.01699): 1 occurrences
# ('track_page', 3.326002): 1 occurrences
# ('login', 2.026974): 1 occurrences
# ('track_page', 9.754002): 1 occurrences
# ('track_page', 26.556002): 1 occurrences
# ('login', 2.00199): 1 occurrences
# ('track_page', 11.309003): 1 occurrences
# ('home_page', 0.000668): 1 occurrences
# ('track_page', 17.28533633): 1 occurrences
# ('track_page', 0.822001): 1 occurrences
# ('login', 0.978978): 1 occurrences
# ('track_page', 19.794003): 1 occurrences
# ('login', 2.017988): 1 occurrences
# ('track_page', 45.340005): 1 occurrences
# ('login', 0.118998): 1 occurrences
# ('track_page', 15.168003): 1 occurrences
# ('login', 2.004998): 1 occurrences
# ('track_page', 31.805002): 1 occurrences
# ('login', 2.010997): 1 occurrences
# ('track_page', 9.255502): 1 occurrences
# ('track_page', 11.325003): 1 occurrences
# ('track_page', 44.649006): 1 occurrences
# ('login', 0.137997): 1 occurrences
# ('track_page', 2.168002): 1 occurrences
# ('track_page', 12.657001): 1 occurrences
# ('track_page', 15.489002): 1 occurrences
# ('login', 2.015984): 1 occurrences
# ('track_page', 55.333002): 1 occurrences
# ('home_page', 0.041003): 1 occurrences
# ('login', 2.009977): 1 occurrences
# ('track_page', 84.428008): 1 occurrences
# ('login', 0.372986): 1 occurrences
# ('track_page', 5.222001): 1 occurrences
# ('track_page', 514.277008): 1 occurrences
# ('login', 0.41799): 1 occurrences
# ('track_page', 1.902001): 1 occurrences
# ('otp_screen_reached', 0.005001): 1 occurrences
# ('track_page', 24.575002): 1 occurrences
# ('login', 0.277989): 1 occurrences
# ('track_page', 395.349998): 1 occurrences
# ('login', 0.87499): 1 occurrences
# ('track_page', 0.741001): 1 occurrences
# ('login', 0.286482): 1 occurrences
# ('login', 2.000985): 1 occurrences
# ('track_page', 2006.87598): 1 occurrences
# ('login', 2.009965): 1 occurrences
# ('track_page', 4.542502): 1 occurrences
# ('track_page', 6.003002): 1 occurrences
# ('track_page', 1.221001): 1 occurrences
# ('login', 0.700991): 1 occurrences
# ('product_category_clicked', 6.807997): 1 occurrences
# ('track_page', 24.634): 1 occurrences
# ('login', 0.106983): 1 occurrences
# ('track_page', 259.815003): 1 occurrences
# ('login', 2.005984): 1 occurrences
# ('track_page', 60.122004): 1 occurrences
# ('login', 2.010983): 1 occurrences
# ('track_page', 44.634003): 1 occurrences
# ('login', 0.12999): 1 occurrences
# ('track_page', 5.223001): 1 occurrences
# ('track_page', 2.282001): 1 occurrences
# ('login', 2.006983): 1 occurrences
# ('track_page', 1018.77801): 1 occurrences
# ('login', 2.091994): 1 occurrences
# ('track_page', 161.252004): 1 occurrences
# ('login', 2.003991): 1 occurrences
# ('track_page', 9.356001333): 1 occurrences
# ('track_page', 4.419001): 1 occurrences
# ('login', 0.225995): 1 occurrences
# ('track_page', 23.810002): 1 occurrences
# ('product_category_clicked', 13.227002): 1 occurrences
# ('order_page', 0.002002): 1 occurrences
# ('track_page', 41.771006): 1 occurrences
# ('login', 2.01198): 1 occurrences
# ('track_page', 83.553007): 1 occurrences
# ('login', 2.011971): 1 occurrences
# ('track_page', 5.384501): 1 occurrences
# ('track_page', 25.952003): 1 occurrences
# ('login', 2.017991): 1 occurrences
# ('track_page', 21.588003): 1 occurrences
# ('login', 2.005975): 1 occurrences
# ('track_page', 23.653005): 1 occurrences
# ('order_page', 0.005003): 1 occurrences
# ('track_page', 344.932987): 1 occurrences
# ('home_page', 0.010009): 1 occurrences
# ('login', 2.03299): 1 occurrences
# ('order_page', 0.004004): 1 occurrences
# ('track_page', 758.989029): 1 occurrences
# ('track_page', 0.7255015): 1 occurrences
# ('login', 0.28196): 1 occurrences
# ('track_page', 5.538001): 1 occurrences
# ('track_page', 120.551008): 1 occurrences
# ('home_page', 0.007006): 1 occurrences
# ('login', 2.005989): 1 occurrences
# ('order_page', 0.007006): 1 occurrences
# ('track_page', 1015.413021): 1 occurrences
# ('home_page', 0.001001666667): 1 occurrences
# ('track_page', 139.707254): 1 occurrences
# ('track_page', 143.243004): 1 occurrences
# ('login', 201.432): 1 occurrences
# ('track_page', 903.667005): 1 occurrences
# ('track_page', 102.460002): 1 occurrences
# ('home_page', 0.008002): 1 occurrences
# ('login', 0.037985): 1 occurrences
# ('track_page', 83.966005): 1 occurrences
# ('login', 2.007966): 1 occurrences
# ('track_page', 1.695001): 1 occurrences
# ('login', 2.050987): 1 occurrences
# ('product_category_clicked', 5.547001): 1 occurrences
# ('product_category_clicked', 19.749004): 1 occurrences
# ('track_page', 15.180001): 1 occurrences
# ('login', 2.008988): 1 occurrences
# ('track_page', 42.462006): 1 occurrences
# ('login', 2.63749): 1 occurrences
# ('track_page', 131.9555015): 1 occurrences
# ('track_page', 11.320001): 1 occurrences
# ('login', 2.02199): 1 occurrences
# ('track_page', 9.577002667): 1 occurrences
# ('track_page', 298.9670015): 1 occurrences
# ('login', 1.995991): 1 occurrences
# ('track_page', 70.108976): 1 occurrences
# ('login', 2.015992): 1 occurrences
# ('track_page', 126.421005): 1 occurrences
# ('track_page', 54.169005): 1 occurrences
# ('track_page', 477.046978): 1 occurrences
# ('track_page', 6.016002): 1 occurrences
# ('track_page', 120.629009): 1 occurrences
# ('track_page', 20.280003): 1 occurrences
# ('login', 2.002999): 1 occurrences
# ('login', 2.000992): 1 occurrences
# ('login', 0.105981): 1 occurrences
# ('track_page', 2.363501): 1 occurrences
# ('track_page', 180.835994): 1 occurrences
# ('login', 2.006978): 1 occurrences
# ('product_category_clicked', 1.474001): 1 occurrences
# ('track_page', 338.400004): 1 occurrences
# ('home_page', 0.016002): 1 occurrences
# ('track_page', 49.516004): 1 occurrences
# ('login', 2.012994): 1 occurrences
# ('track_page', 12.733003): 1 occurrences
# ('login', 2.020985): 1 occurrences
# ('track_page', 29.523003): 1 occurrences
# ('login', 2.009): 1 occurrences
# ('track_page', 13.156502): 1 occurrences
# ('track_page', 77.478011): 1 occurrences
# ('track_page', 0.740001): 1 occurrences
# ('track_page', 8.757004): 1 occurrences
# ('home_page', 0.024001): 1 occurrences
# ('login', 2.000991): 1 occurrences
# ('product_category_clicked', 20.747002): 1 occurrences
# ('track_page', 81.718002): 1 occurrences
# ('login', 1.837986): 1 occurrences
# ('track_page', 3.452998): 1 occurrences
# ('track_page', 984.683): 1 occurrences
# ('track_page', 38.633005): 1 occurrences
# ('product_category_clicked', 9.199002): 1 occurrences
# ('home_page', 0.001335): 1 occurrences
# ('product_category_clicked', 11.237001): 1 occurrences
# ('track_page', 38.04433933): 1 occurrences
# ('login', 2.002977): 1 occurrences
# ('track_page', 2.016997): 1 occurrences
# ('track_page', 1.303002): 1 occurrences
# ('login', 0.883989): 1 occurrences
# ('track_page', 6.332005): 1 occurrences
# ('track_page', 12.9985015): 1 occurrences
# ('otp_screen_reached', 5.921001): 1 occurrences
# ('track_page', 133.604002): 1 occurrences
# ('track_page', 17.865005): 1 occurrences
# ('login', 1.00099): 1 occurrences
# ('track_page', 2.090002): 1 occurrences
# ('track_page', 11.322004): 1 occurrences
# ('login', 2.006984): 1 occurrences
# ('otp_screen_reached', 0.007001): 1 occurrences
# ('product_category_clicked', 24.187002): 1 occurrences
# ('track_page', 4.343001): 1 occurrences
# ('order_page', 0.004002): 1 occurrences
# ('track_page', 204.011009): 1 occurrences
# ('login', 2.040977): 1 occurrences
# ('order_page', 0.005002): 1 occurrences
# ('product_category_clicked', 10.5155015): 1 occurrences
# ('track_page', 122.870503): 1 occurrences
# ('login', 0.479998): 1 occurrences
# ('track_page', 9.216001): 1 occurrences
# ('track_page', 1.755001): 1 occurrences
# ('login', 2.001983): 1 occurrences
# ('track_page', 2039.433998): 1 occurrences
# ('track_page', 110.123006): 1 occurrences
# ('track_page', 28.292006): 1 occurrences
# ('product_category_clicked', 4.693002): 1 occurrences
# ('track_page', 28.293003): 1 occurrences
# ('track_page', 5.276002): 1 occurrences
# ('track_page', 26.171336): 1 occurrences
# ('product_category_clicked', 2.587001): 1 occurrences
# ('login', 2.000987): 1 occurrences
# ('track_page', 285.289001): 1 occurrences
# ('login', 2.012995): 1 occurrences
# ('login', 0.704989): 1 occurrences
# ('track_page', 3.054002): 1 occurrences
# ('login', 3.166552143): 1 occurrences
# ('home_page', 0.001802): 1 occurrences
# ('order_page', 0.004402): 1 occurrences
# ('track_page', 35.6434028): 1 occurrences
# ('otp_screen_reached', 0.004001666667): 1 occurrences
# ('login', 2.0184885): 1 occurrences
# ('home_page', 0.0127545): 1 occurrences
# ('login', 4.7659915): 1 occurrences
# ('track_page', 762.9747245): 1 occurrences
# ('login', 3.071491): 1 occurrences
# ('track_page', 15.4525065): 1 occurrences
# ('login', 2.013994): 1 occurrences
# ('home_page', 0.02700366667): 1 occurrences
# ('order_page', 0.037002): 1 occurrences
# ('track_page', 252.772001): 1 occurrences
# ('home_page', 0.013502): 1 occurrences
# ('track_page', 102.4270075): 1 occurrences
# ('track_page', 698.023007): 1 occurrences
# ('home_page', 0.007004): 1 occurrences
# ('login', 2.0139875): 1 occurrences
# ('order_page', 0.029503): 1 occurrences
# ('track_page', 214.8120072): 1 occurrences
# ('track_page', 3.645002): 1 occurrences
# ('login', 5.0169725): 1 occurrences
# ('login', 2.000989): 1 occurrences
# ('track_page', 17.72001): 1 occurrences
# ('track_page', 3.459002): 1 occurrences
# ('track_page', 12.059005): 1 occurrences
# ('product_category_clicked', 2.374001): 1 occurrences
# ('login', 2.032992): 1 occurrences
# ('track_page', 10.532006): 1 occurrences
# ('order_page', 0.010001): 1 occurrences
# ('product_category_clicked', 4.499001): 1 occurrences
# ('track_page', 299.343004): 1 occurrences
# ('track_page', 241.1290005): 1 occurrences
# ('login', 2.000993): 1 occurrences
# ('order_page', 0.011001): 1 occurrences
# ('track_page', 13.8795015): 1 occurrences
# ('login', 2.002993): 1 occurrences
# ('reward_page', 0.034001): 1 occurrences
# ('login', 2.024986): 1 occurrences
# ('order_page', 0.023002): 1 occurrences
# ('product_category_clicked', 7.829001): 1 occurrences
# ('login', 2.19473625): 1 occurrences
# ('otp_screen_reached', 0.001751): 1 occurrences
# ('product_category_clicked', 12.0670025): 1 occurrences
# ('reward_page', 0.015001): 1 occurrences
# ('track_page', 52.8325025): 1 occurrences
# ('track_page', 154.269002): 1 occurrences
# ('product_category_clicked', 9.623001): 1 occurrences
# ('login', 2.000965): 1 occurrences
# ('track_page', 17.50066533): 1 occurrences
# ('login', 2.048995): 1 occurrences
# ('order_page', 0.005006): 1 occurrences
# ('otp_screen_reached', 0.009005): 1 occurrences
# ('track_page', 142.481005): 1 occurrences
# ('track_page', 3.438001): 1 occurrences
# ('login', 2.01999): 1 occurrences
# ('track_page', 4.207002): 1 occurrences
# ('track_page', 1.046001): 1 occurrences
# ('product_category_clicked', 13.080004): 1 occurrences
# ('home_page', 0.012013): 1 occurrences
# ('order_page', 0.013016): 1 occurrences
# ('product_category_clicked', 8.573502): 1 occurrences
# ('reward_page', 0.003007): 1 occurrences
# ('track_page', 566.294016): 1 occurrences
# ('track_page', 15.2615015): 1 occurrences
# ('product_category_clicked', 4.058001): 1 occurrences
# ('track_page', 18.666001): 1 occurrences
# ('home_page', 0.014009): 1 occurrences
# ('order_page', 0.061011): 1 occurrences
# ('reward_page', 0.014003): 1 occurrences
# ('track_page', 777.684972): 1 occurrences
# ('track_page', 31.902004): 1 occurrences
# ('track_page', 8.620003): 1 occurrences
# ('login', 0.097995): 1 occurrences
# ('track_page', 43.131006): 1 occurrences
# ('login', 2.128988): 1 occurrences
# ('order_page', 0.044001): 1 occurrences
# ('otp_screen_reached', 0.009001): 1 occurrences
# ('reward_page', 0.009001): 1 occurrences
# ('track_page', 136.546006): 1 occurrences
# ('track_page', 0.041): 1 occurrences
# ('login', 2.002996): 1 occurrences
# ('track_page', 6.899002): 1 occurrences
# ('track_page', 35.265501): 1 occurrences
# ('track_page', 4.548001): 1 occurrences
# ('home_page', 0.002005): 1 occurrences
# ('login', 2.008989): 1 occurrences
# ('track_page', 260.248013): 1 occurrences
# ('login', 2.005999): 1 occurrences
# ('track_page', 18.022002): 1 occurrences
# ('login', 2.006987): 1 occurrences
# ('track_page', 165.464012): 1 occurrences
# ('product_category_clicked', 6.125002): 1 occurrences
# ('track_page', 13.445002): 1 occurrences
# ('login', 25.690991): 1 occurrences
# ('otp_screen_reached', 0.003002): 1 occurrences
# ('reward_page', 0.001002): 1 occurrences
# ('track_page', 230.812011): 1 occurrences
# ('track_page', 5.068501): 1 occurrences
# ('login', 2.004977): 1 occurrences
# ('track_page', 0.798001): 1 occurrences
# ('track_page', 7.122002): 1 occurrences
# ('login', 2.00598): 1 occurrences
# ('product_category_clicked', 6.481001): 1 occurrences
# ('login', 1.3584885): 1 occurrences
# ('track_page', 25.901002): 1 occurrences
# ('home_page', 0.0020015): 1 occurrences
# ('home_page', 0.0010025): 1 occurrences
# ('track_page', 340.8959995): 1 occurrences
# ('login', 2.001989): 1 occurrences
# ('login', 0.012989): 1 occurrences
# ('track_page', 121.1005015): 1 occurrences
# ('login', 1.13499): 1 occurrences
# ('track_page', 2e-06): 1 occurrences
# ('track_page', 28.081502): 1 occurrences
# ('home_page', 0.0045045): 1 occurrences
# ('login', 2.416982): 1 occurrences
# ('order_page', 0.0035035): 1 occurrences
# ('reward_page', 0.004004): 1 occurrences
# ('track_page', 147.285016): 1 occurrences
# ('login', 2.003978): 1 occurrences
# ('product_category_clicked', 3.612001): 1 occurrences
# ('login', 2.002997): 1 occurrences
# ('track_page', 171.377957): 1 occurrences
# ('track_page', 41.393002): 1 occurrences
# ('login', 2.003998): 1 occurrences
# ('login', 2.006999): 1 occurrences
# ('track_page', 26.981002): 1 occurrences
# ('product_category_clicked', 20.011002): 1 occurrences
# ('track_page', 29.026008): 1 occurrences
# ('track_page', 63.234011): 1 occurrences
# ('home_page', 3e-06): 1 occurrences
# ('login', 2.007952): 1 occurrences
# ('track_page', 258.125018): 1 occurrences
# ('track_page', 34.523002): 1 occurrences
# ('login', 2.009993): 1 occurrences
# ('track_page', 586.888007): 1 occurrences
# ('login', 0.46199): 1 occurrences
# ('track_page', 61.515002): 1 occurrences
# ('login', 2.027991): 1 occurrences
# ('product_category_clicked', 44.397004): 1 occurrences
# ('track_page', 1.013001): 1 occurrences
# ('track_page', 43.190005): 1 occurrences
# ('track_page', 667.965002): 1 occurrences
# ('login', 2.011995): 1 occurrences
# ('track_page', 624.018003): 1 occurrences
# ('login', 2.001992): 1 occurrences
# ('track_page', 5.963002): 1 occurrences
# ('login', 0.839998): 1 occurrences
# ('track_page', 944.999979): 1 occurrences
# ('login', 2.014989): 1 occurrences
# ('track_page', 69.442003): 1 occurrences
# ('login', 1.99899): 1 occurrences
# ('track_page', 32.964006): 1 occurrences
# ('track_page', 2.405001): 1 occurrences
# ('track_page', 26.517005): 1 occurrences
# ('track_page', 50.9095025): 1 occurrences
# ('track_page', 6.958001): 1 occurrences
# ('track_page', 19.390502): 1 occurrences
# ('login', 0.659984): 1 occurrences
# ('track_page', 10.080003): 1 occurrences
# ('login', 0.740983): 1 occurrences
# ('track_page', 0.758001): 1 occurrences
# ('home_page', 0.011008): 1 occurrences
# ('track_page', 1288.666977): 1 occurrences
# ('track_page', 19.231003): 1 occurrences
# ('track_page', 50.744995): 1 occurrences
# ('track_page', 10.760003): 1 occurrences
# ('track_page', 23.281002): 1 occurrences
# ('login', 0.592995): 1 occurrences
# ('track_page', 15.817003): 1 occurrences
# ('login', 2.004984): 1 occurrences
# ('otp_screen_reached', 0.006002): 1 occurrences
# ('track_page', 65.802002): 1 occurrences
# ('login', 2.014988): 1 occurrences
# ('track_page', 20.579004): 1 occurrences
# ('otp_screen_reached', 0.017007): 1 occurrences
# ('product_category_clicked', 5.576001): 1 occurrences
# ('track_page', 254.097005): 1 occurrences
# ('track_page', 10.807002): 1 occurrences
# ('login', 2.014956): 1 occurrences
# ('track_page', 24.097003): 1 occurrences
# ('track_page', 2.361001): 1 occurrences
# ('track_page', 51.416999): 1 occurrences
# ('login', 0.67299): 1 occurrences
# ('track_page', 2.310002): 1 occurrences
# ('login', 0.564972): 1 occurrences
# ('product_category_clicked', 5.605001): 1 occurrences
# ('track_page', 3.688001): 1 occurrences
# ('track_page', 1.773001): 1 occurrences
# ('track_page', 4.372001): 1 occurrences
# ('login', 1.984992): 1 occurrences
# ('order_page', 0.012003): 1 occurrences
# ('product_category_clicked', 29.308003): 1 occurrences
# ('track_page', 352.165011): 1 occurrences
# ('login', 2.014987): 1 occurrences
# ('login', 2.014996): 1 occurrences
# ('product_category_clicked', 8.687002): 1 occurrences
# ('track_page', 66.056003): 1 occurrences
# ('login', 2.008978): 1 occurrences
# ('otp_screen_reached', 3e-06): 1 occurrences
# ('product_category_clicked', 6.185001): 1 occurrences
# ('track_page', 32.087002): 1 occurrences
# ('track_page', 2.722001): 1 occurrences
# ('login', 2.005983): 1 occurrences
# ('track_page', 22.291003): 1 occurrences
# ('track_page', 3.8575015): 1 occurrences
# ('login', 2.01498): 1 occurrences
# ('track_page', 30.160006): 1 occurrences
# ('login', 0.317984): 1 occurrences
# ('track_page', 3.8525015): 1 occurrences
# ('login', 2.010971): 1 occurrences
# ('track_page', 747.622978): 1 occurrences
# ('track_page', 154.15501): 1 occurrences
# ('track_page', 18.931002): 1 occurrences
# ('track_page', 0.005001): 1 occurrences
# ('product_category_clicked', 11.526002): 1 occurrences
# ('track_page', 36.077009): 1 occurrences
# ('home_page', 0.005004): 1 occurrences
# ('login', 2.013995): 1 occurrences
# ('product_category_clicked', 41.375014): 1 occurrences
# ('track_page', 489.739009): 1 occurrences
# ('order_page', 3e-06): 1 occurrences
# ('track_page', 129.533009): 1 occurrences
# ('login', 1.15749): 1 occurrences
# ('login', 2.0119945): 1 occurrences
# ('track_page', 38.8165015): 1 occurrences
# ('otp_screen_reached', 0.001003): 1 occurrences
# ('track_page', 27.534004): 1 occurrences
# ('track_page', 0.850001): 1 occurrences
# ('login', 0.22199): 1 occurrences
# ('track_page', 6.294001): 1 occurrences
# ('track_page', 1.523001): 1 occurrences
# ('product_category_clicked', 48.249006): 1 occurrences
# ('track_page', 48.142007): 1 occurrences
# ('track_page', 110.114004): 1 occurrences
# ('login', 0.475988): 1 occurrences
# ('track_page', 78.585005): 1 occurrences
# ('track_page', 579.312004): 1 occurrences
# ('track_page', 27.390005): 1 occurrences
# ('login', 2.019986): 1 occurrences
# ('track_page', 4.472002): 1 occurrences
# ('track_page', 43.351002): 1 occurrences
# ('track_page', 23.217004): 1 occurrences
# ('track_page', 15.425002): 1 occurrences
# ('track_page', 17.729005): 1 occurrences
# ('login', 0.099987): 1 occurrences
# ('track_page', 19.5780055): 1 occurrences
# ('login', 2.025991): 1 occurrences
# ('track_page', 106.8890035): 1 occurrences
# ('login', 0.061994): 1 occurrences
# ('product_category_clicked', 4.095001): 1 occurrences
# ('track_page', 7.1905015): 1 occurrences
# ('login', 2.022991): 1 occurrences
# ('track_page', 17.2925035): 1 occurrences
# ('login', 1.999999): 1 occurrences
# ('track_page', 24.1070035): 1 occurrences
# ('product_category_clicked', 1.905001): 1 occurrences
# ('login', 1.984988): 1 occurrences
# ('track_page', 24.433005): 1 occurrences
# ('login', 0.934989): 1 occurrences
# ('track_page', 7.007001): 1 occurrences
# ('home_page', 0.008004): 1 occurrences
# ('product_category_clicked', 31.643003): 1 occurrences
# ('track_page', 43.228009): 1 occurrences
# ('login', 2.004993): 1 occurrences
# ('track_page', 95.282008): 1 occurrences
# ('order_page', 0.004005): 1 occurrences
# ('track_page', 37.541012): 1 occurrences
# ('home_page', 0.004004): 1 occurrences
# ('login', 2.01799): 1 occurrences
# ('track_page', 1277.639015): 1 occurrences
# ('track_page', 1.474001): 1 occurrences
# ('home_page', 0.003008): 1 occurrences
# ('product_category_clicked', 11.835002): 1 occurrences
# ('track_page', 2450.049993): 1 occurrences
# ('track_page', 13.089002): 1 occurrences
# ('product_category_clicked', 9.499001): 1 occurrences
# ('track_page', 272.229): 1 occurrences
# ('track_page', 1193.580998): 1 occurrences
# ('login', 2.001994): 1 occurrences
# ('otp_screen_reached', 0.004002): 1 occurrences
# ('track_page', 32.200003): 1 occurrences
# ('home_page', 0.001004): 1 occurrences
# ('track_page', 455.447993): 1 occurrences
# ('track_page', 27.541994): 1 occurrences
# ('track_page', 787.409995): 1 occurrences
# ('track_page', 66.93): 1 occurrences
# ('login', 2.011993): 1 occurrences
# ('home_page', 0.006007): 1 occurrences
# ('login', 2.006976): 1 occurrences
# ('track_page', 211.253015): 1 occurrences
# ('product_category_clicked', 1.943001): 1 occurrences
# ('track_page', 2.085001): 1 occurrences
# ('track_page', 21.651002): 1 occurrences
# ('login', 2.013996): 1 occurrences
# ('track_page', 152.682002): 1 occurrences
# ('login', 1.998997): 1 occurrences
# ('track_page', 8.920003): 1 occurrences
# ('track_page', 32.379): 1 occurrences
# ('track_page', 344.656001): 1 occurrences
# ('login', 2.02499): 1 occurrences
# ('track_page', 8.299002): 1 occurrences
# ('login', 1.0664895): 1 occurrences
# ('track_page', 36.3215015): 1 occurrences
# ('track_page', 52.393002): 1 occurrences
# ('track_page', 38.119981): 1 occurrences
# ('product_category_clicked', 15.827003): 1 occurrences
# ('track_page', 17.898003): 1 occurrences
# ('product_category_clicked', 19.424003): 1 occurrences
# ('product_category_clicked', 42.885003): 1 occurrences
# ('track_page', 5.448002): 1 occurrences
# ('login', 2.025967): 1 occurrences
# ('track_page', 91.691016): 1 occurrences
# ('login', 2.006986): 1 occurrences
# ('track_page', 385.7845): 1 occurrences
# ('home_page', 0.019001): 1 occurrences
# ('track_page', 251.775973): 1 occurrences
# ('home_page', 0.040001): 1 occurrences
# ('login', 2.242993): 1 occurrences
# ('track_page', 14.278002): 1 occurrences
# ('login', 2.002995): 1 occurrences
# ('product_category_clicked', 19.867002): 1 occurrences
# ('login', 2.087995): 1 occurrences
# ('track_page', 6.631001): 1 occurrences
# ('login', 2.019993): 1 occurrences
# ('track_page', 0.004001): 1 occurrences
# ('track_page', 7.252002): 1 occurrences
# ('track_page', 0.003001): 1 occurrences
# ('login', 2.002987): 1 occurrences
# ('track_page', 24.236002): 1 occurrences
# ('login', 1.989999): 1 occurrences
# ('product_category_clicked', 3.059001): 1 occurrences
# ('track_page', 152.667003): 1 occurrences
# ('login', 0.258989): 1 occurrences
# ('track_page', 1.468001): 1 occurrences
# ('track_page', 1412.951002): 1 occurrences
# ('login', 2.002989): 1 occurrences
# ('track_page', 293.2120023): 1 occurrences
# ('login', 1.998987): 1 occurrences
# ('track_page', 49.4999995): 1 occurrences
# ('login', 2.006975): 1 occurrences
# ('login', 4.02896): 1 occurrences
# ('login', 2.051992): 1 occurrences
# ('login', 2.010991): 1 occurrences
# ('login', 2.008992): 1 occurrences
# ('order_page', 0.003501): 1 occurrences
# ('track_page', 188.9295055): 1 occurrences
# ('login', 1.999988): 1 occurrences
# ('track_page', 1.553501): 1 occurrences
# ('track_page', 47.855003): 1 occurrences
# ('login', 1.079988): 1 occurrences
# ('track_page', 1.021501): 1 occurrences
# ('login', 0.799988): 1 occurrences
# ('track_page', 18.530002): 1 occurrences
# ('login', 2.008974): 1 occurrences
# ('track_page', 27.739002): 1 occurrences
# ('track_page', 2.616001): 1 occurrences
# ('login', 2.022992): 1 occurrences
# ('track_page', 25.034002): 1 occurrences
# ('track_page', 18.896002): 1 occurrences
# ('login', 2.009982): 1 occurrences
# ('track_page', 355.886005): 1 occurrences
# ('track_page', 2.691001): 1 occurrences
# ('home_page', 0.006502): 1 occurrences
# ('order_page', 0.005001): 1 occurrences
# ('product_category_clicked', 28.082003): 1 occurrences
# ('track_page', 48.245004): 1 occurrences
# ('login', 2.001984): 1 occurrences
# ('track_page', 450.672005): 1 occurrences
# ('login', 2.003996): 1 occurrences
# ('product_category_clicked', 11.307001): 1 occurrences
# ('track_page', 1659.947966): 1 occurrences
# ('track_page', 51.430002): 1 occurrences
# ('home_page', 0.021005): 1 occurrences
# ('login', 1.992993): 1 occurrences
# ('order_page', 0.011003): 1 occurrences
# ('track_page', 400.910995): 1 occurrences
# ('track_page', 28.564002): 1 occurrences
# ('order_page', 0.025004): 1 occurrences
# ('track_page', 43.431007): 1 occurrences
# ('login', 2.112998): 1 occurrences
# ('otp_screen_reached', 0.012001): 1 occurrences
# ('track_page', 34.076005): 1 occurrences
# ('login', 0.888997): 1 occurrences
# ('product_category_clicked', 3.007001): 1 occurrences
# ('track_page', 3.941001): 1 occurrences
# ('track_page', 270.691986): 1 occurrences
# ('track_page', 900.655004): 1 occurrences
# ('order_page', 0.0005015): 1 occurrences
# ('track_page', 304.6603343): 1 occurrences
# ('login', 2.003976): 1 occurrences
# ('track_page', 20.750002): 1 occurrences
# ('login', 2.007976): 1 occurrences
# ('track_page', 1.939001): 1 occurrences
# ('product_category_clicked', 13.981001): 1 occurrences
# ('track_page', 9.838002): 1 occurrences
# ('login', 2.03499): 1 occurrences
# ('login', 2.019998): 1 occurrences
# ('product_category_clicked', 12.203998): 1 occurrences
# ('login', 2.005): 1 occurrences
# ('track_page', 8.623001): 1 occurrences
# ('login', 1.996996): 1 occurrences
# ('product_category_clicked', 2.755002): 1 occurrences
# ('track_page', 6.520004): 1 occurrences
# ('track_page', 19.077004): 1 occurrences
# ('login', 2.001998): 1 occurrences
# ('login', 1.333987): 1 occurrences
# ('track_page', 2.871003): 1 occurrences
# ('login', 0.624988): 1 occurrences
# ('track_page', 2.9625015): 1 occurrences
# ('login', 2.006998): 1 occurrences
# ('track_page', 665.471001): 1 occurrences
# ('track_page', 110.383003): 1 occurrences
# ('login', 2.011996): 1 occurrences
# ('track_page', 0.597001): 1 occurrences
# ('track_page', 12.917001): 1 occurrences
# ('login', 2.009992): 1 occurrences
# ('track_page', 7.926501): 1 occurrences
# ('login', 0.177988): 1 occurrences
# ('track_page', 8.348501): 1 occurrences
# ('home_page', 0.0025055): 1 occurrences
# ('reward_page', 0.0010015): 1 occurrences
# ('track_page', 1292.457509): 1 occurrences
# ('track_page', 38.0095015): 1 occurrences
# ('track_page', 38.712004): 1 occurrences
# ('track_page', 2.430001): 1 occurrences
# ('login', 2.010999): 1 occurrences
# ('track_page', 0.005002): 1 occurrences
# ('track_page', 183.471006): 1 occurrences
# ('product_category_clicked', 22.616002): 1 occurrences
# ('track_page', 85.758979): 1 occurrences
# ('track_page', 5.022002): 1 occurrences
# ('login', 2.000983): 1 occurrences
# ('product_category_clicked', 5.851002): 1 occurrences
# ('track_page', 1.538003): 1 occurrences
# ('track_page', 51.72667067): 1 occurrences
# ('login', 1.496659667): 1 occurrences
# ('track_page', 1.235501): 1 occurrences
# ('track_page', 53.80567567): 1 occurrences
# ('login', 2.00565): 1 occurrences
# ('otp_screen_reached', 0.000668): 1 occurrences
# ('track_page', 38.8640025): 1 occurrences
# ('login', 2.000653667): 1 occurrences
# ('login', 2.0174915): 1 occurrences
# ('product_category_clicked', 6.0175015): 1 occurrences
# ('track_page', 29.86433567): 1 occurrences
# ('home_page', 0.001336333333): 1 occurrences
# ('track_page', 304.8840083): 1 occurrences
# ('login', 2.0069915): 1 occurrences
# ('track_page', 328.5906687): 1 occurrences
# ('home_page', 0.002003666667): 1 occurrences
# ('track_page', 307.9356677): 1 occurrences
# ('login', 2.002992667): 1 occurrences
# ('track_page', 602.229006): 1 occurrences
# ('login', 1.577993): 1 occurrences
# ('otp_screen_reached', 0.001334333333): 1 occurrences
# ('track_page', 1.315001): 1 occurrences
# ('login', 2.005325333): 1 occurrences
# ('otp_screen_reached', 0.0010015): 1 occurrences
# ('home_page', 0.001502): 1 occurrences
# ('login', 2.015985): 1 occurrences
# ('track_page', 97.9305025): 1 occurrences
# ('home_page', 0.0010015): 1 occurrences
# ('login', 2.0059855): 1 occurrences
# ('track_page', 50.525337): 1 occurrences
# ('home_page', 0.008006): 1 occurrences
# ('login', 1.129989): 1 occurrences
# ('order_page', 0.0115035): 1 occurrences
# ('track_page', 241.5350025): 1 occurrences
# ('login', 2.0089945): 1 occurrences
# ('track_page', 640.689666): 1 occurrences
# ('login', 2.0059955): 1 occurrences
# ('track_page', 952.529991): 1 occurrences
# ('login', 3.008981): 1 occurrences
# ('track_page', 209.1130075): 1 occurrences
# ('home_page', 0.0025025): 1 occurrences
# ('login', 2.0079915): 1 occurrences
# ('track_page', 69.56666267): 1 occurrences
# ('login', 1.234491): 1 occurrences
# ('track_page', 502.701499): 1 occurrences
# ('home_page', 0.00300325): 1 occurrences
# ('login', 2.004988): 1 occurrences
# ('order_page', 0.000668): 1 occurrences
# ('track_page', 180.566757): 1 occurrences
# ('track_page', 499.1459915): 1 occurrences
# ('login', 2.0079895): 1 occurrences
# ('track_page', 2.010003): 1 occurrences
# ('home_page', 0.002502): 1 occurrences
# ('login', 2.0169855): 1 occurrences
# ('track_page', 38.022503): 1 occurrences
# ('product_category_clicked', 39.0530035): 1 occurrences
# ('track_page', 19.926502): 1 occurrences
# ('login', 2.0074855): 1 occurrences
# ('track_page', 17.54825475): 1 occurrences
# ('login', 2.010996): 1 occurrences
# ('login', 1.4459885): 1 occurrences
# ('track_page', 92.36800467): 1 occurrences
# ('track_page', 47.1940085): 1 occurrences
# ('home_page', 0.01303433333): 1 occurrences
# ('login', 2.674609667): 1 occurrences
# ('track_page', 259.3277133): 1 occurrences
# ('login', 1.417991): 1 occurrences
# ('track_page', 641.350996): 1 occurrences
# ('login', 2.0059885): 1 occurrences
# ('track_page', 78.62267533): 1 occurrences
# ('home_page', 0.0006676666667): 1 occurrences
# ('login', 2.005321667): 1 occurrences
# ('track_page', 91.74175275): 1 occurrences
# ('login', 2.00348): 1 occurrences
# ('track_page', 9.660667667): 1 occurrences
# ('home_page', 1.5e-06): 1 occurrences
# ('login', 1.2389685): 1 occurrences
# ('track_page', 352.912003): 1 occurrences
# ('login', 2.0049955): 1 occurrences
# ('track_page', 893.447493): 1 occurrences
# ('home_page', 0.010501): 1 occurrences
# ('login', 1.413992): 1 occurrences
# ('track_page', 41.663002): 1 occurrences

# %%
def round_durations(filtered_pages):
    return [(event, round(duration, 2)) for event, duration in filtered_pages]

# Apply the rounding function to the 'Filtered Pages' column
df_successful['Filtered Pages'] = df_successful['Filtered Pages'].apply(round_durations)

# Print the updated DataFrame
df_successful
# Out:
#        user_id                                     Filtered Pages
# 0    100160846  [(home_page, 0.0), (login, 2.01), (otp_screen_...
# 1    100405016  [(login, 0.89), (session_start, 0.0), (track_p...
# 2    100412287  [(home_page, 0.0), (login, 0.74), (otp_screen_...
# 3    100428671  [(login, 2.01), (otp_screen_reached, 0.0), (se...
# 4    100448405  [(login, 1.06), (otp_screen_reached, 0.01), (s...
# ..         ...                                                ...
# 238  745064767  [(home_page, 0.0), (login, 2.01), (otp_screen_...
# 239  746059301  [(login, 2.0), (session_start, 0.0), (track_pa...
# 240  772746004  [(home_page, 0.0), (login, 1.24), (otp_screen_...
# 241  791728308               [(login, 2.0), (track_page, 893.45)]
# 242  792066937  [(session_start, 0.0), (home_page, 0.01), (log...
#
# [243 rows x 2 columns]

# %%
from collections import Counter

# Extract sequences and their durations
sequences = df_successful['Filtered Pages'].apply(lambda x: str(x))
sequences = sequences.apply(eval)

# Calculate total session durations for each sequence
sequence_durations = sequences.apply(lambda x: sum([page[1] for page in x]))

# Combine sequences and their durations into a list of tuples
sequence_duration_tuples = list(zip(sequences, sequence_durations))

# Count the occurrences of each sequence
sequence_counts = Counter([tuple(seq) for seq, dur in sequence_duration_tuples])

# Get the most common sequences
common_sequences = sequence_counts.most_common()

# Display the most common sequences and their durations
common_sequences_durations = [(seq, count, sum([page[1] for page in seq])) for seq, count in common_sequences]

# Convert to DataFrame for better visualization
common_sequences_df = pd.DataFrame(common_sequences_durations, columns=['Sequence', 'Count', 'Total Duration'])

print(common_sequences_df.head())
# Out:
#                                             Sequence  Count  Total Duration
# 0                                   ((login, 2.01),)      4            2.01
# 1  ((login, 2.0), (otp_screen_reached, 0.0), (ses...      2            2.00
# 2  ((login, 2.01), (otp_screen_reached, 0.0), (se...      2            2.01
# 3  ((login, 2.0), (otp_screen_reached, 0.0), (ses...      2            2.00
# 4  ((home_page, 0.0), (login, 2.01), (otp_screen_...      1           84.75

# %%
common_sequences_df
# Out:
#                                               Sequence  Count  Total Duration
# 0                                     ((login, 2.01),)      4            2.01
# 1    ((login, 2.0), (otp_screen_reached, 0.0), (ses...      2            2.00
# 2    ((login, 2.01), (otp_screen_reached, 0.0), (se...      2            2.01
# 3    ((login, 2.0), (otp_screen_reached, 0.0), (ses...      2            2.00
# 4    ((home_page, 0.0), (login, 2.01), (otp_screen_...      1           84.75
# ..                                                 ...    ...             ...
# 232  ((home_page, 0.0), (login, 2.01), (otp_screen_...      1           93.75
# 233  ((login, 2.0), (session_start, 0.0), (track_pa...      1           11.66
# 234  ((home_page, 0.0), (login, 1.24), (otp_screen_...      1          354.15
# 235               ((login, 2.0), (track_page, 893.45))      1          895.45
# 236  ((session_start, 0.0), (home_page, 0.01), (log...      1           43.08
#
# [237 rows x 3 columns]

# %%
from collections import Counter

# Extract sequences and their durations
sequences = df_successful['Filtered Pages'].apply(lambda x: str(x))
sequences = sequences.apply(eval)

# Calculate total session durations for each sequence
sequence_durations = sequences.apply(lambda x: sum([page[1] for page in x]))

# Combine sequences and their durations into a list of tuples
sequence_duration_tuples = list(zip(sequences, sequence_durations))

# Count the occurrences of each sequence
sequence_counts = Counter([tuple(seq) for seq, dur in sequence_duration_tuples])

# Get the most common sequences
common_sequences = sequence_counts.most_common()

# Display the most common sequences and their durations
common_sequences_durations = [(seq, count, sum([page[1] for page in seq])) for seq, count in common_sequences]

# Convert to DataFrame for better visualization
common_sequences_df = pd.DataFrame(common_sequences_durations, columns=['Sequence', 'Count', 'Total Duration'])

# %%
common_sequences_df.head()
# Out:
#                                             Sequence  Count  Total Duration
# 0  ((home_page, 0.001001), (login, 2.006991), (ot...      1       84.744495
# 1  ((login, 0.894998), (session_start, 0.0), (tra...      1       10.247967
# 2  ((home_page, 0.003002), (login, 0.739989), (ot...      1      131.624003
# 3  ((login, 2.009991), (otp_screen_reached, 0.001...      1        3.449493
# 4  ((login, 1.064979), (otp_screen_reached, 0.007...      1        1.071983
